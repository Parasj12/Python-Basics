# %% [markdown]
# # Pandas Exercise: Basic Stats (Wind Statistics)

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data=pd.read_csv('https://raw.githubusercontent.com/Parasj12/Python-Basics/master/Datasets/Pandas%20Exercise7%20Files/wind.data',sep='\s+',parse_dates={'Date':[0,1,2]})
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
pd.read_csv?

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
import datetime as dt

# %%
def func(col):
    if col.year>2018:
        year=col.year-100
    else:
        year=col.year
    return dt.date(year,col.month,col.day)

# %%
data['Date']=data['Date'].apply(func)
data.head()
# Out:
#          Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data=data.set_index('Date')
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame()

# %%
loc_stats['mean']=data.mean(skipna=True)
loc_stats['min']=data.min(skipna=True)
loc_stats['max']=data.max(skipna=True)
loc_stats['std']=data.std(skipna=True)
loc_stats.head()
# Out:
#           mean   min    max       std
# RPT  12.362987  0.67  35.80  5.618413
# VAL  10.644314  0.21  33.37  5.267356
# ROS  11.660526  1.50  33.84  5.008450
# KIL   6.306468  0.00  28.46  3.605811
# SHA  10.455834  0.13  37.54  4.936125

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=pd.DataFrame()

# %%
day_stats['mean']=data.mean(axis=1,skipna=True)
day_stats['min']=data.min(axis=1,skipna=True)
day_stats['max']=data.max(axis=1,skipna=True)
day_stats['std']=data.std(axis=1,skipna=True)
day_stats.head()
# Out:
#                  mean   min    max       std
# Date
# 1961-01-01  13.018182  9.29  18.50  2.808875
# 1961-01-02  11.336364  6.50  17.54  3.188994
# 1961-01-03  11.641818  6.17  18.50  3.681912
# 1961-01-04   6.619167  1.79  11.75  3.198126
# 1961-01-05  10.630000  6.17  13.33  2.445356

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data['Date']=data.index
data['year']=data['Date'].apply(lambda x:x.year)
data['month']=data['Date'].apply(lambda x:x.month)
data['day']=data['Date'].apply(lambda x:x.day)

# %%
 data.iloc[:,:-3][data.month==1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data[(data.month==1)&(data.day==1)].head()
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1962-01-01   9.29   3.42  11.54   3.50   2.21   1.96  10.41   2.79   3.54
# 1963-01-01  15.59  13.62  19.79   8.38  12.25  10.00  23.45  15.71  13.59
# 1964-01-01  25.80  22.13  18.21  13.25  21.29  14.79  14.12  19.58  13.25
# 1965-01-01   9.54  11.92   9.00   4.38   6.08   5.21  10.25   6.08   5.71
#
#               CLO    BEL    MAL        Date  year  month  day
# Date
# 1961-01-01  12.58  18.50  15.04  1961-01-01  1961      1    1
# 1962-01-01   5.17   4.38   7.92  1962-01-01  1962      1    1
# 1963-01-01  14.37  17.58  34.13  1963-01-01  1963      1    1
# 1964-01-01  16.75  28.96  21.00  1964-01-01  1964      1    1
# 1965-01-01   8.63  12.04  17.41  1965-01-01  1965      1    1

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data[(data.day==1)].head()
# Out:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17  9.29    NaN   9.87  13.67  10.25  10.83
# 1961-02-01  14.25  15.12   9.04  5.88  12.08   7.17  10.17   3.63   6.50
# 1961-03-01  12.67  13.13  11.79  6.42   9.79   8.54  10.25  13.29    NaN
# 1961-04-01   8.38   6.34   8.33  6.75   9.33   9.54  11.67   8.21  11.21
# 1961-05-01  15.87  13.88  15.37  9.79  13.46  10.17   9.96  14.04   9.75
#
#               CLO    BEL    MAL        Date  year  month  day
# Date
# 1961-01-01  12.58  18.50  15.04  1961-01-01  1961      1    1
# 1961-02-01   5.50   9.17   8.00  1961-02-01  1961      2    1
# 1961-03-01  12.21  20.62    NaN  1961-03-01  1961      3    1
# 1961-04-01   6.46  11.96   7.17  1961-04-01  1961      4    1
# 1961-05-01   9.92  18.63  11.12  1961-05-01  1961      5    1

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data[::7].head()
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25
# 1961-01-15  12.04   9.67  11.75   2.37   7.38   3.13   2.50   6.83   4.75
# 1961-01-22   9.59   5.88   9.92   2.17   6.87   5.50   9.38   7.04   6.34
# 1961-01-29    NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
#
#               CLO    BEL    MAL        Date  year  month  day  monthno
# Date
# 1961-01-01  12.58  18.50  15.04  1961-01-01  1961      1    1      210
# 1961-01-08  10.46  16.62  16.46  1961-01-08  1961      1    8      210
# 1961-01-15   5.63   7.54   6.75  1961-01-15  1961      1   15      210
# 1961-01-22   7.50  10.88   9.92  1961-01-22  1961      1   22      210
# 1961-01-29  19.95  27.71  23.38  1961-01-29  1961      1   29      210

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
data1=pd.read_csv('https://raw.githubusercontent.com/Parasj12/Python-Basics/master/Datasets/Pandas%20Exercise7%20Files/wind.data',sep='\s+')
data1['month_no'] = (data1.Yr -61) * 12 + data1.Mo
data1.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL  month_no
# 0  12.58  18.50  15.04         1
# 1   9.67  17.54  13.83         1
# 2   7.67  12.75  12.71         1
# 3   5.88   5.46  10.88         1
# 4  10.34  12.92  11.83         1

# %%
data1.groupby('month_no').mean().head()
# Out:
#             Yr   Mo    Dy        RPT        VAL        ROS       KIL  \
# month_no
# 1         61.0  1.0  16.0  14.841333  11.988333  13.431613  7.736774
# 2         61.0  2.0  14.5  16.269286  14.975357  14.441481  9.230741
# 3         61.0  3.0  16.0  10.890000  11.296452  10.752903  7.284000
# 4         61.0  4.0  15.5  10.722667   9.427667   9.998000  5.830667
# 5         61.0  5.0  16.0   9.860968   8.850000  10.818065  5.905333
#
#                 SHA        BIR        DUB        CLA        MUL        CLO  \
# month_no
# 1         11.072759   8.588065  11.184839   9.245333   9.085806  10.107419
# 2         13.852143  10.937500  11.890714  11.846071  11.821429  12.714286
# 3         10.509355   8.866774   9.644194   9.829677  10.294138  11.251935
# 4          8.435000   6.495000   6.925333   7.094667   7.342333   7.237000
# 5          9.490323   6.574839   7.604000   8.177097   8.039355   8.499355
#
#                 BEL        MAL
# month_no
# 1         13.880968  14.703226
# ...

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL        Date  year  month  day  monthno
# Date
# 1961-01-01  12.58  18.50  15.04  1961-01-01  1961      1    1      210
# 1961-01-02   9.67  17.54  13.83  1961-01-02  1961      1    2      210
# 1961-01-03   7.67  12.75  12.71  1961-01-03  1961      1    3      210
# 1961-01-04   5.88   5.46  10.88  1961-01-04  1961      1    4      210
# 1961-01-05  10.34  12.92  11.83  1961-01-05  1961      1    5      210

# %%
data.index=pd.to_datetime(data.index)
data.iloc[1:, :].resample('W').agg(['min','max','mean','std'])[:52]
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Date
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
# 1961-03-19   4.92  16.88  11.911429  3.860036   9.46  15.54  13.501429
# ...
