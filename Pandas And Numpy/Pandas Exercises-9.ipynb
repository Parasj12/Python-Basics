# %% [markdown]
# # Pandas Exercise: Time Series (Getting Financial Data - Google Finance)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import quandl

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
start=pd.datetime(2015,1,1)
end=pd.datetime.today()
start,end
# Out:
# (datetime.datetime(2015, 1, 1, 0, 0),
#  datetime.datetime(2018, 8, 7, 16, 14, 0, 156864))

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stocks = ['EOD/AAPL', 'SSE/TL0', 'EOD/IBM']

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
quandl.ApiConfig.api_key = 'QA7iUAs_11R6Ui2Y6m2_'

# %%
df = quandl.get(stocks, start_date = start, end_date = end)
df.head()
# Out:
#             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2015-01-02           111.39           111.44         107.350
# 2015-01-05           108.29           108.65         105.410
# 2015-01-06           106.54           107.43         104.630
# 2015-01-07           107.20           108.20         106.695
# 2015-01-08           109.23           112.15         108.700
#
#             EOD/AAPL - Close  EOD/AAPL - Volume  EOD/AAPL - Dividend  \
# Date
# 2015-01-02            109.33         53204626.0                  0.0
# 2015-01-05            106.25         64285491.0                  0.0
# 2015-01-06            106.26         65797116.0                  0.0
# 2015-01-07            107.75         40105934.0                  0.0
# 2015-01-08            111.89         59364547.0                  0.0
#
#             EOD/AAPL - Split  EOD/AAPL - Adj_Open  EOD/AAPL - Adj_High  \
# Date
# 2015-01-02               1.0           104.612862           104.659820
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
df.info
# Out:
# <bound method DataFrame.info of             EOD/AAPL - Open  EOD/AAPL - High  EOD/AAPL - Low  \
# Date
# 2015-01-02         111.3900         111.4400        107.3500
# 2015-01-05         108.2900         108.6500        105.4100
# 2015-01-06         106.5400         107.4300        104.6300
# 2015-01-07         107.2000         108.2000        106.6950
# 2015-01-08         109.2300         112.1500        108.7000
# 2015-01-09         112.6700         113.2500        110.2100
# 2015-01-12         112.6000         112.6300        108.8000
# 2015-01-13         111.4300         112.8000        108.9100
# 2015-01-14         109.0400         110.4900        108.5000
# 2015-01-15         110.0000         110.0600        106.6600
# 2015-01-16         107.0300         107.5800        105.2000
# 2015-01-19              NaN              NaN             NaN
# 2015-01-20         107.8400         108.9667        106.5000
# 2015-01-21         108.9500         111.0600        108.2700
# ...

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
df.columns
# Out:
# Index(['EOD/AAPL - Open', 'EOD/AAPL - High', 'EOD/AAPL - Low',
#        'EOD/AAPL - Close', 'EOD/AAPL - Volume', 'EOD/AAPL - Dividend',
#        'EOD/AAPL - Split', 'EOD/AAPL - Adj_Open', 'EOD/AAPL - Adj_High',
#        'EOD/AAPL - Adj_Low', 'EOD/AAPL - Adj_Close', 'EOD/AAPL - Adj_Volume',
#        'SSE/TL0 - High', 'SSE/TL0 - Low', 'SSE/TL0 - Last',
#        'SSE/TL0 - Previous Day Price', 'SSE/TL0 - Volume', 'EOD/IBM - Open',
#        'EOD/IBM - High', 'EOD/IBM - Low', 'EOD/IBM - Close',
#        'EOD/IBM - Volume', 'EOD/IBM - Dividend', 'EOD/IBM - Split',
#        'EOD/IBM - Adj_Open', 'EOD/IBM - Adj_High', 'EOD/IBM - Adj_Low',
#        'EOD/IBM - Adj_Close', 'EOD/IBM - Adj_Volume'],
#       dtype='object')

# %%
vol['SSE/TL0 - Volume'].tail()
# Out:
# Date
# 2018-07-31    263.0
# 2018-08-01    292.0
# 2018-08-02    790.0
# 2018-08-03    775.0
# 2018-08-06    577.0
# Name: SSE/TL0 - Volume, dtype: float64

# %%
vol = df[['EOD/AAPL - Volume', 'SSE/TL0 - Volume', 'EOD/IBM - Adj_Volume']]
vol.tail()
# Out:
#             EOD/AAPL - Volume  SSE/TL0 - Volume  EOD/IBM - Adj_Volume
# Date
# 2018-07-31         39373038.0             263.0             5474166.0
# 2018-08-01         67935716.0             292.0             3387370.0
# 2018-08-02         62404012.0             790.0             3836675.0
# 2018-08-03         33447396.0             775.0             8053557.0
# 2018-08-06         25425387.0             577.0             3913743.0

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol['week']=vol.index.week
vol['year']=vol.index.year
vol.groupby(['week','year']).sum()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            EOD/AAPL - Volume  SSE/TL0 - Volume  EOD/IBM - Adj_Volume
# week year
# 1    2015         53204626.0               0.0             5525341.0
#      2016        343790211.0               0.0            25251873.0
# ...

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
vol[vol.year==2015]
# Out:
#             EOD/AAPL - Volume  SSE/TL0 - Volume  EOD/IBM - Adj_Volume  week  \
# Date
# 2015-01-02         53204626.0               NaN             5525341.0     1
# 2015-01-05         64285491.0               NaN             4880389.0     2
# 2015-01-06         65797116.0               NaN             6145670.0     2
# 2015-01-07         40105934.0               NaN             4701015.0     2
# 2015-01-08         59364547.0               NaN             4240585.0     2
# 2015-01-09         53315099.0               NaN             4472701.0     2
# 2015-01-12         49650790.0               NaN             4187588.0     3
# 2015-01-13         67091928.0               NaN             4386989.0     3
# 2015-01-14         48956588.0               NaN             4689740.0     3
# 2015-01-15         60013996.0               NaN             4251698.0     3
# 2015-01-16         78513345.0               NaN             5756041.0     3
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
